# %% [markdown]
# # Extracting Haiku(ish things) from Wikipedia
#
# This is an experiment in found poetry, done mostly to try out some Python libraries I haven't used before (Allison Parrish's pronouncingpy and CLiPs's pattern.
#
# First I need some text to work with.

# %%
from pattern.web import (Wikipedia, WikipediaArticle)

enwiki = Wikipedia('en')

raw_text = enwiki.search('cat').string

# %% [markdown]
# Ok, I have some text. It's got a lot of garbage and punctuation I don't care about, though, so let's get rid of that and turn it into a list of words.

# %%
import re

# A word is uppercase or lowercase letters, maybe apostrophes, maybe hyphens
words_re = re.compile(r"[A-Za-z]+")

def words(text):
    return [word.lower() for word in words_re.findall(text)]
    
# For example:
print words("Some! garbage[0] text I can't   use.very.well,?hUh")
# Out:
# ['some', 'garbage', 'text', 'i', 'can', 't', 'use', 'very', 'well', 'huh']

# %%
# Now, the article:
article_words = words(raw_text)
# truncated for readability
print article_words[0:5]
# Out:
# [u'this', u'article', u'is', u'about', u'the']

# %% [markdown]
# Haiku follow a fairly strict convention of syllable counts; the classic pattern is 5-7-5. So I'll need to be able to figure out how many syllables a word has. For that, I'll use pronouncing.

# %%
import pronouncing

def syllables(word):
    try:
        return pronouncing.syllable_count(pronouncing.phones_for_word(word)[0]) # just uses the first pronunciation
    except:
        return 17 # don't use this word if we don't know how many syllables it is

print syllables("pronouncing")
# Out:
# 3

# %% [markdown]
# Now comes the tricky part. Given a list of words, how can I determine whether some subset of that list can form a valid haiku?
#
# Well, first I'll need to be able to tell if a set of words could form a line of five or seven syllables.

# %%
def get_line(word_list, syllable_goal):
    line = []
    syllable_count = 0
    for word in word_list:
        line.append(word)
        syllable_count += syllables(word)
        if syllable_count == syllable_goal:
            return line
        elif syllable_count > syllable_goal:
            # failed; can't make a line of the right length
            return None

print get_line(words("I can make five here"), 5)
print get_line(words("...but here it's impossible."), 5)

print get_line(words("here is a seven-count line"), 7)
# Out:
# ['i', 'can', 'make', 'five', 'here']
# None
# ['here', 'is', 'a', 'seven', 'count', 'line']

# %% [markdown]
# So, what is a haiku? A five-syllable line, followed by a seven-syllable line, followed by a five-syllable line. We can try to extract a haiku from a list of words by looking for those lines, in order.

# %%
def attempt_haiku(word_list):
    haiku = []
    remaining_words = word_list + [] # copy word list to avoid mutating it
    for length in [5, 7, 5]:
        line = get_line(remaining_words, length)
        if line == None:
            return None # failure
        else: # found a line
            haiku.append(line)
            remaining_words = remaining_words[len(line):] # discard the words we're already using
    return haiku

print "\nReal haiku attempt:\n"
print attempt_haiku(words("""
Start spirit; behold
the skull. A living head loved
earth. My bones resign
""")) # haiku from here: https://www.poets.org/poetsorg/poem/lines-skull

article_haiku = attempt_haiku(article_words)
print "\nArticle about cats attempt:\n"
print article_haiku

# Wow, first try! Let's make it prettier.

def print_haiku(haiku):
    print "\n" # let it breathe
    for line in haiku:
        print ' '.join(line)
    print "\n"

print_haiku(article_haiku)
# Out:
# Real haiku attempt:
#
# [['start', 'spirit', 'behold'], ['the', 'skull', 'a', 'living', 'head', 'loved'], ['earth', 'my', 'bones', 'resign']]
#
# Article about cats attempt:
#
# [[u'this', u'article', u'is'], [u'about', u'the', u'cat', u'species', u'that'], [u'is', u'commonly', u'kept']]
#
#
# this article is
# about the cat species that
# is commonly kept

# %% [markdown]
# I got lucky this time, but this isn't quite enough for further searching, because it will only find a haiku at the beginning of an article. To find a haiku deeper in the article, we can just try again with the first word dropped until we find something or the article ends. In fact, it'd be nice to find _all_ of the haiku that we can in the article (no overlaps, though -- you have to have standards in poetry).

# %%
def get_all_haiku(article_words):
    all_haiku = []
    while len(article_words) > 0:
        haiku = attempt_haiku(article_words)
        if haiku:
            print_haiku(haiku)
            # ugh, why can't I just call haiku.flatten(), Python?
            haiku_word_count = len([word for line in haiku for word in line])
            all_haiku.append(haiku)
            article_words = article_words[haiku_word_count:] # drop the words we used
        else:
            article_words = article_words[1:]
    return all_haiku
            
# Uncomment this to get all the haiku! (Github won't display it otherwise)
# print get_all_haiku(article_words)
# Out:
# this article is
# about the cat species that
# is commonly kept
#
#
#
#
# typically furry
# carnivorous mammal they
# are often called house
#
#
#
#
# as indoor pets or
# simply cats when there is no
# need to distinguish
#
#
#
#
# and felines cats are
# often valued by humans
# for companionship
#
#
#
#
# ability to
# hunt vermin there are more than
# cat breeds different
#
#
#
#
# associations
# proclaim different numbers
# according to their
#
#
#
#
# a strong flexible
# body quick reflexes sharp
# retractable claws
#
#
#
#
# and predatory
# ecological niche cats
# can hear sounds too faint
#
#
#
#
# in frequency for
# human ears such as those made
# by mice and other
#
#
#
#
# small animals they
# can see in near darkness like
# most other mammals
#
#
#
#
# have poorer color
# vision and a better sense
# of smell than humans
#
#
#
#
# cats despite being
# solitary hunters are
# a social species
#
#
#
#
# and grunting as well
# as cat pheromones and types
# of cat specific
#
#
#
#
# have a high breeding
# rate under controlled breeding
# they can be bred and
#
#
#
#
# shown as registered
# pedigree pets a hobby
# known as cat fancy
#
#
#
#
# failure to control
# the breeding of pet cats by
# neutering and the
#
#
#
#
# of former household
# pets has resulted in large
# numbers of feral
#
#
#
#
# other factors to
# the extinction of many
# bird species cats have
#
#
#
#
# extirpate a bird
# species within specific
# regions and may have
#
#
#
#
# to the extinction
# of isolated island
# populations cats
#
#
#
#
# for the extinction
# of species of birds and the
# presence of feral
#
#
#
#
# reintroduction
# in otherwise suitable
# locations since cats
#
#
#
#
# were venerated
# in ancient egypt they were
# commonly believed
#
#
#
#
# in west asia a
# study found that leopard cats
# were undergoing
#
#
#
#
# domesticated
# populations of today
# as of a study
#
#
#
#
# cats are the second
# most popular pet in the
# united states by
#
#
#
#
# are a rapidly
# evolving family of
# mammals that share a
#
#
#
#
# common ancestor
# only million years ago
# and include lions
#
#
#
#
# part of the genus
# felis which is a group of
# small cats containing
#
#
#
#
# species depending
# upon classification
# scheme members of the
#
#
#
#
# worldwide and include
# the jungle cat felis chaus
# of southeast asia
#
#
#
#
# the arabian
# sand cat f margarita
# among others the
#
#
#
#
# this has resulted
# in mixed usage of the terms
# as the domestic
#
#
#
#
# on zoological
# nomenclature fixed the name
# for wildcats as f
#
#
#
#
# synonym proposed
# sometimes the domestic cat
# has been called felis
#
#
#
#
# proposed by german
# naturalist j c p
# erxleben in but
#
#
#
#
# this population
# is considered to be a
# part of domestic
#
#
#
#
# cats in this genus
# share a common ancestor
# that probably lived
#
#
#
#
# uncertain e g
# the chinese mountain cat is
# sometimes classified
#
#
#
#
# have not undergone
# major changes during the
# domestication
#
#
#
#
# domestic cat is
# not radically different
# from those of wildcats
#
#
#
#
# and domestic cats
# are perfectly capable
# of surviving in
#
#
#
#
# pets these traits include
# their small size social nature
# obvious body
#
#
#
#
# relationship with
# humans two main theories are
# given about how
#
#
#
#
# in a process of
# artificial selection
# as they were useful
#
#
#
#
# has been criticized
# as implausible because
# the reward for such
#
#
#
#
# have been too little
# cats generally do not
# carry out commands
#
#
#
#
# and although they do
# eat rodents other species
# such as ferrets or
#
#
#
#
# that cats were simply
# tolerated by people
# and gradually
#
#
#
#
# diverged from their wild
# relatives through natural
# selection as they
#
#
#
#
# many languages
# is english puss pussycat
# attested only
#
#
#
#
# etymology
# of this word is unknown but
# it may have simply
#
#
#
#
# arisen from a
# sound used to attract a cat
# a group of cats is
#
#
#
#
# or a glaring a
# male cat is called a tom or
# tomcat or a gib
#
#
#
#
# female is called a
# queen and a juvenile cat
# is referred to as
#
#
#
#
# its sire and its
# female progenitor is
# its dam in early
#
#
#
#
# the word kitten was
# interchangeable with the
# now obsolete word
#
#
#
#
# organization
# a purebred cat is one whose
# ancestry contains
#
#
#
#
# of unrecorded
# mixed ancestry are referred
# to as domestic
#
#
#
#
# which domestic cats
# are descended and wildcats
# and domestic cats
#
#
#
#
# mostly outdoor cat
# is not owned by any one
# individual
#
#
#
#
# associated
# with human habitation
# areas and may
#
#
#
#
# be fed by people
# or forage for food but are
# typically wary
#
#
#
#
# domestic cats are
# similar in size to the
# other members of
#
#
#
#
# feral cats tend to
# be lighter as they have more
# limited access
#
#
#
#
# food than house cats in
# the boston area the
# average feral
#
#
#
#
# head body length males
# being larger than females
# with tails averaging
#
#
#
#
# vertebrae like most
# mammals humans have five and
# a variable
#
#
#
#
# caudal vertebrae
# in the tail humans retain
# three to five caudal
#
#
#
#
# the extra lumbar
# and thoracic vertebrae
# account for the cat
#
#
#
#
# mobility and
# flexibility attached
# to the spine are ribs
#
#
#
#
# unlike human arms
# cat forelimbs are attached to
# the shoulder by free
#
#
#
#
# which allow them to
# pass their body through any
# space into which they
#
#
#
#
# can fit their head the
# cat skull is unusual
# among mammals in
#
#
#
#
# eye sockets and a
# powerful and specialized
# jaw within the jaw
#
#
#
#
# and tearing meat when
# it overpowers its prey
# a cat delivers
#
#
#
#
# neck bite with its two
# long canine teeth inserting
# them between two of
#
#
#
#
# and death compared to
# other felines domestic
# cats have narrowly
#
#
#
#
# spaced canine teeth which
# is an adaptation to
# their preferred prey of
#
#
#
#
# pair on each side of
# the mouth which efficiently
# shears meat into small
#
#
#
#
# pieces like a pair
# of scissors these are vital
# in feeding since cats
#
#
#
#
# to have better teeth
# than most humans with decay
# generally less
#
#
#
#
# of enamel a
# less damaging saliva
# less retention of
#
#
#
#
# particles between
# teeth and a diet mostly
# devoid of sugar
#
#
#
#
# nonetheless subject
# to occasional tooth loss
# and infection cats
#
#
#
#
# they walk directly
# on their toes with the bones of
# their feet making up
#
#
#
#
# visible leg cats
# are capable of walking
# very precisely
#
#
#
#
# like all felines they
# directly register that
# is they place each hind
#
#
#
#
# the corresponding
# fore paw minimizing noise
# and visible tracks
#
#
#
#
# this also provides
# sure footing for their hind paws
# when they navigate
#
#
#
#
# rough terrain unlike
# most mammals when cats walk they
# use a pacing gait
#
#
#
#
# that is they move the
# two legs on one side of the
# body before the
#
#
#
#
# on the other side
# this trait is shared with camels
# and giraffes as a
#
#
#
#
# into a trot a
# cat s gait changes to be
# a diagonal
#
#
#
#
# gait similar to
# that of most other mammals
# and many other
#
#
#
#
# hind and fore legs move
# simultaneously like
# almost all members
#
#
#
#
# and retractable
# claws in their normal relaxed
# position the claws
#
#
#
#
# are sheathed with the skin
# and fur around the paw s
# toe pads this keeps the
#
#
#
#
# by preventing wear
# from contact with the ground and
# allows the silent
#
#
#
#
# of prey the claws on
# the fore feet are typically
# sharper than those on
#
#
#
#
# the hind feet cats can
# voluntarily extend
# their claws on one or
#
#
#
#
# may extend their claws
# in hunting or self defense
# climbing kneading or
#
#
#
#
# for extra traction
# on soft surfaces most cats
# have five claws on their
#
#
#
#
# four on their rear paws
# the fifth front claw the dewclaw
# is proximal to
#
#
#
#
# which appears to be
# a sixth finger this special
# feature of the front
#
#
#
#
# paws on the inside
# of the wrists is the carpal
# pad also found on
#
#
#
#
# the paws of big cats
# and dogs it has no function
# in normal walking
#
#
#
#
# extra toes and claws
# these are particularly
# common along the
#
#
#
#
# animals and their
# physiology has been
# particularly
#
#
#
#
# mammals but displays
# several unusual
# features probably
#
#
#
#
# attributable
# to cats descent from desert
# dwelling species for
#
#
#
#
# temperatures humans
# generally start to feel
# uncomfortable
#
#
#
#
# c f but cats show
# no discomfort until their
# skin reaches around
#
#
#
#
# up to c f if
# they have access to water
# cats conserve heat by
#
#
#
#
# to their skin and lose
# heat by evaporation
# through their mouths cats have
#
#
#
#
# with glands located
# primarily in their paw
# pads and pant for heat
#
#
#
#
# relief only at
# very high temperatures but
# may also pant when
#
#
#
#
# a cat s body
# temperature does not vary
# throughout the day this
#
#
#
#
# cats general lack
# of circadian rhythms
# and may reflect their
#
#
#
#
# both during the day
# and at night cats feces are
# comparatively
#
#
#
#
# urine is highly
# concentrated both of which
# are adaptations
#
#
#
#
# cats to retain as
# much water as possible
# their kidneys are so
#
#
#
#
# seawater cats are
# obligate carnivores their
# physiology
#
#
#
#
# about protein in
# their diet about of a
# cat s diet must
#
#
#
#
# rapidly fatal
# another unusual
# feature is that the
#
#
#
#
# blindness a cat s
# gastrointestinal tract
# is adapted to
#
#
#
#
# of the digestive
# enzymes needed to digest
# carbohydrates these
#
#
#
#
# severely limit
# the cat s ability
# to digest and use
#
#
#
#
# derived nutrients
# as well as certain fatty
# acids despite the
#
#
#
#
# vegetarian
# or vegan cat foods have been
# marketed that are
#
#
#
#
# produce a complete
# diet however some of
# these products still fail
#
#
#
#
# diets containing
# no animal products pose
# the risk of causing
#
#
#
#
# occasionally
# a proposed explanation
# is that cats use grass
#
#
#
#
# a source of folic
# acid another proposed
# explanation is
#
#
#
#
# cat senses cats have
# excellent night vision and
# can see at only
#
#
#
#
# level required
# for human vision this is
# partly the result
#
#
#
#
# through the retina
# back into the eye thereby
# increasing the eye
#
#
#
#
# dim light another
# adaptation to dim light
# is the large pupils
#
#
#
#
# of cats eyes unlike
# some big cats such as tigers
# domestic cats have
#
#
#
#
# the domestic cat
# s pupils are much larger
# relative to their
#
#
#
#
# eyes than the pupils
# of the big cats at low light
# levels a cat s
#
#
#
#
# its eyes however
# domestic cats have rather
# poor color vision
#
#
#
#
# sensitivity
# to blue and yellowish green
# they have limited
#
#
#
#
# between red and green
# a paper reported a
# response to middle
#
#
#
#
# a system other
# than the rods which might be due
# to a third type of
#
#
#
#
# this appears to be
# an adaptation to low
# light levels rather
#
#
#
#
# cats have excellent
# hearing and can detect an
# extremely broad range
#
#
#
#
# they can hear higher
# pitched sounds than either dogs or
# humans detecting
#
#
#
#
# a range of octaves
# while humans and dogs both have
# ranges of about
#
#
#
#
# which is important
# in hunting because many
# species of rodents
#
#
#
#
# and among the best
# of any mammal being
# most acute in the
#
#
#
#
# amplify sounds and
# help detect the direction
# of a noise cats have
#
#
#
#
# sense of smell due in
# part to their well developed
# olfactory bulb
#
#
#
#
# area which is
# about twice that of humans
# cats are sensitive
#
#
#
#
# communicate through
# urine spraying and marking
# with scent glands many
#
#
#
#
# they can detect that
# substance at less than one part
# per billion about
#
#
#
#
# valerian it
# may be caused by the smell of
# these plants mimicking
#
#
#
#
# and stimulating
# cats social or sexual
# behaviors cats have
#
#
#
#
# relatively few
# taste buds compared to humans
# or so versus more
#
#
#
#
# on the human tongue
# domestic and wild cats share
# a gene mutation
#
#
#
#
# keeps their sweet taste buds
# from binding to sugary
# molecules leaving
#
#
#
#
# no ability
# to taste sweetness their taste buds
# instead respond to
#
#
#
#
# amino acids
# bitter tastes and acids cats
# and many other
#
#
#
#
# have a jacobson
# s organ located in
# their mouths that allows
#
#
#
#
# certain aromas
# in a way which humans have
# no experience
#
#
#
#
# preference for their
# food preferring food with a
# temperature around
#
#
#
#
# that of a fresh kill
# and routinely rejecting
# food presented cold
#
#
#
#
# refrigerated
# which would signal to the cat
# that the prey item
#
#
#
#
# possibly toxic
# decomposing to aid with
# navigation and
#
#
#
#
# faces these provide
# information on the width
# of gaps and on the
#
#
#
#
# of objects in the
# dark both by touching objects
# directly and by
#
#
#
#
# they also trigger
# protective blink reflexes
# to protect the eyes
#
#
#
#
# damage most breeds of
# cat have a noted fondness
# for settling in
#
#
#
#
# the wild a higher
# place may serve as a concealed
# site from which to hunt
#
#
#
#
# domestic cats may
# strike prey by pouncing from a
# perch such as a tree
#
#
#
#
# leopard another
# possible explanation
# is that height gives the
#
#
#
#
# observation point
# allowing it to survey
# its territory
#
#
#
#
# fall from a high place
# a cat can reflexively
# twist its body and
#
#
#
#
# itself using its
# acute sense of balance and
# flexibility
#
#
#
#
# always rights itself
# in the same way provided
# it has the time to
#
#
#
#
# do so during a
# fall the height required for
# this to occur is
#
#
#
#
# cats without a tail
# e g manx cats also have
# this ability
#
#
#
#
# since a cat mostly
# moves its hind legs and relies
# on conservation
#
#
#
#
# momentum to set
# up for landing and the tail
# is little used for
#
#
#
#
# article cat health
# the average lifespan of
# pet cats has risen
#
#
#
#
# recent years in the
# early s it was about
# seven years rising
#
#
#
#
# years in however
# cats have been reported as
# surviving into
#
#
#
#
# s with the oldest
# known cat creme puff dying at
# a verified age
#
#
#
#
# life expectancy
# one study found neutered male
# cats live twice as long
#
#
#
#
# as intact males while
# spayed female cats live longer
# than intact females
#
#
#
#
# the welfare of free
# roaming cats the lifespans of
# neutered feral cats
#
#
#
#
# colonies compare
# favorably with those of
# pet cats neutered cats
#
#
#
#
# vaccinations are
# available for many
# of these diseases
#
#
#
#
# given treatments to
# eliminate parasites
# such as worms and fleas
#
#
#
#
# poisoned by many
# chemicals usually
# considered safe by
#
#
#
#
# human guardians
# because their livers are less
# effective at some
#
#
#
#
# humans and dogs some
# of the most common causes
# of poisoning in
#
#
#
#
# cats are antifreeze
# and rodent baits cats may be
# particularly
#
#
#
#
# sudden or prolonged
# serious illness without
# any obvious
#
#
#
#
# human medicines
# should never be given to
# cats for example
#
#
#
#
# even very small
# doses need immediate
# treatment and can be
#
#
#
#
# which is sometimes used
# to treat arthritis in cats
# is much more toxic
#
#
#
#
# be administered
# cautiously similarly
# application of
#
#
#
#
# to the skin of cats
# either accidentally
# or by well meaning
#
#
#
#
# to counter loss of
# fur has sometimes been fatal
# essential oils can
#
#
#
#
# and cases have been
# reported of serious
# illnesses caused by
#
#
#
#
# shampoos containing
# it other common household
# substances that should
#
#
#
#
# caution around cats
# include mothballs and other
# naphthalene products
#
#
#
#
# litter boxes but
# these can sometimes be fatal
# ethylene glycol
#
#
#
#
# cats and as little
# as a teaspoonful can be
# fatal some human
#
#
#
#
# poisoning although
# unlike dogs few cats will eat
# chocolate large amounts
#
#
#
#
# roughly genes about
# heritable genetic
# disorders have been
#
#
#
#
# many similar
# to human inborn errors
# the high level of
#
#
#
#
# feline diseases
# to be diagnosed using
# genetic tests that
#
#
#
#
# use in humans as
# well as the use of cats as
# animal models
#
#
#
#
# cat behavior and
# cat intelligence outdoor
# cats are active both
#
#
#
#
# day and night although
# they tend to be slightly more
# active at night the
#
#
#
#
# activity is
# quite flexible and varied
# which means house cats may
#
#
#
#
# more active in the
# morning and evening as a
# response to greater
#
#
#
#
# activity at
# these times although they spend the
# majority of
#
#
#
#
# range many hundreds
# of meters from this central
# point and are known to
#
#
#
#
# one study ranging
# from to hectares acres cats
# conserve energy
#
#
#
#
# by sleeping more than
# most animals especially
# as they grow older
#
#
#
#
# and hours with and
# being the average some
# cats can sleep as much
#
#
#
#
# the term cat nap for
# a short rest refers to the
# cat s tendency
#
#
#
#
# lightly for a brief
# period while asleep cats
# experience short
#
#
#
#
# rapid eye movement
# sleep often accompanied
# by muscle twitches
#
#
#
#
# are solitary
# the social behavior of
# domestic cats is
#
#
#
#
# variable and
# ranges from widely dispersed
# individuals
#
#
#
#
# a food source based on
# groups of co operating
# females within such
#
#
#
#
# dominant over
# the others each cat in a
# colony holds a
#
#
#
#
# territory with
# sexually active males
# having the largest
#
#
#
#
# territories which
# are about times larger than
# those of female cats
#
#
#
#
# territories these
# territories are marked by
# urine spraying by
#
#
#
#
# rubbing objects at
# head height with secretions from
# facial glands and by
#
#
#
#
# these territories
# are neutral areas where
# cats watch and greet one
#
#
#
#
# another without
# territorial conflicts
# outside these neutral
#
#
#
#
# usually chase
# away stranger cats at first
# by staring hissing
#
#
#
#
# and if that does not
# work by short but noisy and
# violent attacks
#
#
#
#
# always hunt alone
# however some pet cats are
# poorly socialized
#
#
#
#
# though cats and dogs are
# believed to be natural
# enemies they can
#
#
#
#
# live together if
# correctly socialized life
# in proximity
#
#
#
#
# adaptation in
# cats and cats may express great
# affection toward
#
#
#
#
# human keeper of
# a cat may function as a
# sort of surrogate
#
#
#
#
# make to solicit
# food may mimic the cries of
# a hungry human
#
#
#
#
# infant making them
# particularly hard for
# humans to ignore
#
#
#
#
# contrast feral cats
# are generally silent
# their types of body
#
#
#
#
# language including
# position of ears and tail
# relaxation of
#
#
#
#
# the whole body and
# kneading of the paws are all
# indicators of
#
#
#
#
# particularly
# important social signal
# mechanisms in
#
#
#
#
# for example a
# raised tail acts as a friendly
# greeting and flattened
#
#
#
#
# also indicates
# the cat s position in
# the group s social
#
#
#
#
# individuals
# raising their tails less often
# than subordinate
#
#
#
#
# animals nose to
# nose touching is also a
# common greeting and
#
#
#
#
# social grooming which
# is solicited by one
# of the cats raising
#
#
#
#
# have developed as
# an evolutionary
# advantage as a
#
#
#
#
# kittens post nursing
# cats often purr as a sign
# of contentment when
#
#
#
#
# for the sound it was
# until recent times believed
# that only the cats
#
#
#
#
# and leopard also
# produce sounds similar to
# purring but only
#
#
#
#
# are known for spending
# considerable amounts
# of time licking their
#
#
#
#
# coat to keep it clean
# the cat s tongue has backwards
# facing spines about
#
#
#
#
# that have collected
# in their stomachs from grooming
# these clumps of fur are
#
#
#
#
# with remedies that
# ease elimination of
# the hair through the gut
#
#
#
#
# well as regular
# grooming of the coat with a
# comb or stiff brush some
#
#
#
#
# can develop a
# compulsive behavior known
# as psychogenic
#
#
#
#
# males are more likely
# to fight than females among
# feral cats the most
#
#
#
#
# for cat fighting is
# competition between two
# males to mate with a
#
#
#
#
# cases most fights are
# won by the heavier male
# another common
#
#
#
#
# reason for fighting
# in domestic cats is the
# difficulty of
#
#
#
#
# female cats also
# fight over territory
# or to defend their
#
#
#
#
# or eliminate
# this behavior in many
# cases suggesting
#
#
#
#
# the behavior is
# linked to sex hormones when cats
# become aggressive
#
#
#
#
# make themselves appear
# larger and more threatening
# by raising their fur
#
#
#
#
# turning sideways and
# hissing or spitting often
# the ears are pointed
#
#
#
#
# and back to avoid
# damage to the inner ear
# and potentially
#
#
#
#
# changes behind them
# while focused forward they may
# also vocalize
#
#
#
#
# teeth in an effort
# to further intimidate
# their opponent fights
#
#
#
#
# and delivering
# powerful slaps to the face
# and body with the
#
#
#
#
# bites cats also throw
# themselves to the ground in a
# defensive posture
#
#
#
#
# their opponent s
# belly with their powerful
# hind legs serious
#
#
#
#
# damage is rare as
# the fights are usually
# short in duration
#
#
#
#
# the loser running
# away with little more than
# a few scratches to
#
#
#
#
# fights for mating rights
# are typically more severe
# and injuries may
#
#
#
#
# to infections of
# scratches and bites though these can
# occasionally
#
#
#
#
# in addition bites
# are probably the main route
# of transmission of
#
#
#
#
# during their lives and
# often have decidedly
# battered faces with
#
#
#
#
# primarily birds
# and rodents and are often
# used as a form of
#
#
#
#
# cats are a major
# predator of wildlife in
# the united states
#
#
#
#
# and billion mammals
# annually the bulk of
# predation in the
#
#
#
#
# united states is
# done by million feral and
# stray cats effective
#
#
#
#
# opposition from
# cat enthusiasts in the
# case of free ranging
#
#
#
#
# equipping cats with
# bells and not letting them out
# at night will reduce
#
#
#
#
# wildlife predation
# free fed feral cats and house
# cats tend to consume
#
#
#
#
# many small meals in
# a single day although the
# frequency and size
#
#
#
#
# cats use two hunting
# strategies either stalking
# prey actively or
#
#
#
#
# waiting in ambush
# until an animal comes
# close enough to be
#
#
#
#
# although it is not
# certain the strategy used
# may depend on the
#
#
#
#
# prey species in the
# area with cats waiting
# in ambush outside
#
#
#
#
# stalk birds perhaps the
# best known element of cats
# hunting behavior
#
#
#
#
# which is commonly
# misunderstood and often
# appalls cat owners
#
#
#
#
# because it looks like
# torture is that cats often
# appear to play with
#
#
#
#
# to an instinctive
# imperative to ensure
# that the prey is weak
#
#
#
#
# enough to be killed
# without endangering the
# cat this behavior
#
#
#
#
# is referred to in
# the idiom cat and mouse
# game or simply cat
#
#
#
#
# poorly understood
# element of cat hunting
# behavior is the
#
#
#
#
# cats adopt humans
# into their social group and
# share excess kill with
#
#
#
#
# according to the
# dominance hierarchy
# in which humans are
#
#
#
#
# they are at or near
# the top anthropologist
# and zoologist
#
#
#
#
# when cats bring home mice
# or birds they are attempting
# to teach their human
#
#
#
#
# or trying to help
# their human as if feeding
# an elderly cat
#
#
#
#
# an inept kitten
# morris s hypothesis
# is inconsistent
#
#
#
#
# male cats also bring
# home prey despite males having
# no involvement with
#
#
#
#
# kittens domestic
# cats select food based on its
# temperature smell and
#
#
#
#
# foods and respond most
# strongly to moist foods rich in
# amino acids
#
#
#
#
# are similar to
# meat cats may reject novel
# flavors a response
#
#
#
#
# and learn quickly to
# avoid foods that have tasted
# unpleasant in the
#
#
#
#
# past they may also
# avoid sugary foods and
# milk most adult cats
#
#
#
#
# sugars in milk are
# not easily digested
# and may cause soft stools
#
#
#
#
# or diarrhea
# they can also develop
# odd eating habits
#
#
#
#
# some cats like to eat
# or chew on other things most
# commonly wool but
#
#
#
#
# coal this condition
# pica can threaten their health
# depending on the
#
#
#
#
# and toxicity
# of the items eaten though
# cats usually
#
#
#
#
# on animals less
# than half their size a feral
# cat in australia
#
#
#
#
# lb since cats cannot
# fully close their lips around
# something to create
#
#
#
#
# a lapping method
# with the tongue to draw liquid
# upwards into their
#
#
#
#
# mouths lapping at a
# rate of four times a second
# the cat touches the
#
#
#
#
# tip of its tongue to
# the surface of the water
# and quickly retracts
#
#
#
#
# and toys domestic
# cats especially young kittens
# are known for their love
#
#
#
#
# behavior mimics
# hunting and is important
# in helping kittens
#
#
#
#
# to stalk capture and
# kill prey cats also engage
# in play fighting with
#
#
#
#
# each other and with
# humans this behavior may
# be a way for cats
#
#
#
#
# to practice the skills
# needed for real combat and
# might also reduce
#
#
#
#
# associate with
# launching attacks on other
# animals owing
#
#
#
#
# similarity
# between play and hunting cats
# prefer to play with
#
#
#
#
# that resemble prey
# such as small furry toys that
# move rapidly but
#
#
#
#
# in a toy they have
# played with before cats also
# tend to play with toys
#
#
#
#
# when they are hungry
# string is often used as a
# toy but if it is
#
#
#
#
# can become caught at
# the base of the cat s tongue
# and then move into
#
#
#
#
# emergency which
# can cause serious illness
# even death owing
#
#
#
#
# by cats eating string
# it is sometimes replaced with
# a laser pointer
#
#
#
#
# which cats may chase there
# are several important
# issues related
#
#
#
#
# using a laser
# with a cat first most lasers
# can cause blindness in
#
#
#
#
# cats even lasers
# which are sold as eye safe can
# actually be
#
#
#
#
# much higher power
# of that proclaimed and can cause
# damages to the
#
#
#
#
# eyes in addition
# the cat thinks of the laser
# point as prey but gets
#
#
#
#
# which means they may have
# many periods of heat
# over the course of
#
#
#
#
# in late autumn heat
# periods occur about
# every two weeks
#
#
#
#
# and last about to
# days multiple males will be
# attracted to a
#
#
#
#
# female in heat the
# males will fight over her and
# the victor wins the
#
#
#
#
# to mate at first the
# female rejects the male but
# eventually
#
#
#
#
# as the male pulls out
# of her because a male cat
# s penis has a
#
#
#
#
# withdrawal of the
# penis the spines rake the walls
# of the female s
#
#
#
#
# which is a trigger
# for ovulation this act
# also occurs to
#
#
#
#
# the vagina of
# other sperm in the context
# of a second or
#
#
#
#
# mating thus giving
# the later males a larger
# chance of conception
#
#
#
#
# after mating the
# female washes her vulva
# thoroughly if a
#
#
#
#
# mate with her at this
# point the female will attack
# him after about
#
#
#
#
# once the female is
# finished grooming the cycle
# will repeat because
#
#
#
#
# mating females may
# not be impregnated by
# the first male with which
#
#
#
#
# that is a female
# may mate with more than one male
# when she is in heat
#
#
#
#
# period for cats
# is between and days with an
# average of days
#
#
#
#
# size of a litter
# usually is three to
# five kittens with the
#
#
#
#
# subsequent litters
# kittens are weaned between six
# and seven weeks old
#
#
#
#
# cats normally reach
# sexual maturity
# at months females and
#
#
#
#
# to months males although
# this can vary depending
# on breed females can
#
#
#
#
# two to three litters
# per year so may produce up
# to kittens in their
#
#
#
#
# of around ten years
# cats are ready to go to
# new homes at about
#
#
#
#
# when they are ready
# to leave their mother they can
# be surgically
#
#
#
#
# reproduction this
# surgery also prevents
# undesirable
#
#
#
#
# traditionally
# this surgery was performed
# at around six to
#
#
#
#
# months of age but it
# is increasingly being
# performed prior to
#
#
#
#
# at about three to
# six months in the us about
# of household cats are
#
#
#
#
# across much of the
# world geneticist stephen
# james o brien of
#
#
#
#
# evolution s
# most charismatic creatures
# they can live on the
#
#
#
#
# and in the hottest
# deserts they are extremely
# adaptable and
#
#
#
#
# on all continents
# except antarctica and
# on of the main groups
#
#
#
#
# feral cats can live
# in forests grasslands tundra
# coastal areas
#
#
#
#
# urban areas
# and wetlands their habitats
# even include small
#
#
#
#
# behaviors the cat
# s ability to thrive
# in almost any
#
#
#
#
# habitat has led
# to its designation as
# one of the world s
#
#
#
#
# domestic cats are
# little altered from wildcats
# they can readily
#
#
#
#
# distinctiveness of
# some wildcat populations
# particularly
#
#
#
#
# feral cat feral
# cats are domestic cats that
# were born in or have
#
#
#
#
# to a wild state they
# are unfamiliar with and
# wary of humans
#
#
#
#
# freely in urban
# and rural areas the
# numbers of feral
#
#
#
#
# estimates of the
# us feral population
# range from to million
#
#
#
#
# feral cats may live
# alone but most are found in
# large colonies which
#
#
#
#
# are usually
# associated with a
# source of food famous
#
#
#
#
# given medical
# attention by volunteers
# public attitudes
#
#
#
#
# towards feral cats
# vary widely ranging from
# seeing them as free
#
#
#
#
# regarding them as
# vermin one common approach
# to reducing the
#
#
#
#
# cat population
# is termed trap neuter return
# where the cats are trapped
#
#
#
#
# into their feral
# colonies the attending
# veterinarian
#
#
#
#
# the tip off one ear
# to mark it as neutered and
# inoculated
#
#
#
#
# may be trapped again
# volunteers continue to
# feed and give care to
#
#
#
#
# these cats throughout their
# lives given this support their
# lifespans are increased
#
#
#
#
# nuisance problems caused
# by competition for food
# are reduced impact
#
#
#
#
# is available
# to assess the impact of
# cat predation on
#
#
#
#
# prey populations
# even well fed domestic
# cats may hunt and kill
#
#
#
#
# by domestic cats
# may be contributing to
# the decline in the
#
#
#
#
# numbers of birds in
# urban areas although
# the importance of
#
#
#
#
# this effect remains
# controversial in the wild
# the introduction
#
#
#
#
# human settlement
# can threaten native species
# with extinction in
#
#
#
#
# cases controlling
# or eliminating the
# populations of
#
#
#
#
# of introduced cats
# can be more complicated
# for example cats
#
#
#
#
# control the numbers
# of rats which also prey on
# birds eggs and young so
#
#
#
#
# as australasia
# there are often no other
# native medium
#
#
#
#
# including other
# feline species this tends to
# exacerbate the
#
#
#
#
# feral cats on small
# native animals native
# species such as the
#
#
#
#
# example tend to
# be more ecologically
# vulnerable and
#
#
#
#
# faced with predation
# by cats feral cats have had
# a major impact
#
#
#
#
# native species and
# have played a leading role in
# the endangerment
#
#
#
#
# even in places
# with ancient and numerous
# cat populations
#
#
#
#
# growing in number
# and independently of
# their environments
#
#
#
#
# such as the numbers
# of prey available this
# may be explained at
#
#
#
#
# and scavenging for
# instance research in britain
# suggests that a high
#
#
#
#
# million bird deaths each
# year certain species appear
# more susceptible
#
#
#
#
# mortality is
# linked to the domestic cat
# in the recovery
#
#
#
#
# a result of cat
# predation the presence of
# larger carnivores
#
#
#
#
# and raccoons on bird
# numbers and variety
# the proposal that
#
#
#
#
# populations will
# increase when the numbers of
# these top predators
#
#
#
#
# however a new
# study suggests cats are a
# much greater menace
#
#
#
#
# cats kill several
# billion birds each year in the
# united states on
#
#
#
#
# birds can contribute
# as much as of a cat s
# diet in nearly
#
#
#
#
# however the cat
# cannot be identified
# as the sole cause for
#
#
#
#
# numbers of island
# birds and in some instances
# eradication
#
#
#
#
# where the suppression
# of top carnivores creates
# an abundance of
#
#
#
#
# predators that cause
# a severe decline in their
# shared prey domestic
#
#
#
#
# a contributing
# factor to the decline of
# many species a
#
#
#
#
# a few from a long
# list with the most extreme case
# being the flightless
#
#
#
#
# wren which was driven
# to extinction only a
# few years after its
#
#
#
#
# the same factors that
# have promoted adaptive
# radiation of
#
#
#
#
# appear to promote
# vulnerability to
# non native species
#
#
#
#
# in modern time the
# susceptibility of
# many island birds
#
#
#
#
# undoubtedly due
# to evolution in the
# absence of mainland
#
#
#
#
# rates and extended
# incubation periods
# the loss of flight or
#
#
#
#
# ability is
# also characteristic
# of many island
#
#
#
#
# aspects have increased
# vulnerability to
# extinction in the
#
#
#
#
# species such as the
# domestic cat equally
# behavioral traits
#
#
#
#
# contributed to
# their susceptibility
# interaction with
#
#
#
#
# article human
# interaction with cats cats
# are common pets in
#
#
#
#
# associated
# with women a gallup poll
# reported that men
#
#
#
#
# in the united
# states of america were
# equally likely
#
#
#
#
# to own a cat as
# well as being kept as pets
# cats are also used
#
#
#
#
# international
# fur and leather industries
# for making coats hats
#
#
#
#
# cats are needed to
# make a cat fur coat this use
# has now been outlawed
#
#
#
#
# states australia and
# the european union
# cat pelts have been used
#
#
#
#
# for superstitious
# purposes as part of the
# practise of witchcraft
#
#
#
#
# in switzerland as
# folk remedies believed to
# help rheumatism
#
#
#
#
# idea of cats
# as everyday objects have
# served to illustrate
#
#
#
#
# thought experiment
# a few attempts to build a
# cat census have been
#
#
#
#
# made over the years
# both through associations
# or national and
#
#
#
#
# international
# organizations such as
# the canadian
#
#
#
#
# federation of
# humane societies s
# one and over the
#
#
#
#
# achieve general
# estimates for the global
# population of
#
#
#
#
# depictions of cats
# and cats in ancient egypt
# traditionally
#
#
#
#
# egypt was the site
# of cat domestication
# owing to the clear
#
#
#
#
# cyprus contained the
# skeletons laid close to one
# another of both
#
#
#
#
# and a cat the grave
# is estimated to be
# years old pushing back
#
#
#
#
# association
# significantly the cat
# specimen is large
#
#
#
#
# wildcat rather than
# present day domestic cats
# this discovery
#
#
#
#
# genetic studies
# suggests cats were probably
# domesticated
#
#
#
#
# east in the fertile
# crescent around the time of
# the development
#
#
#
#
# agriculture and
# then they were brought to cyprus
# and egypt direct
#
#
#
#
# university
# of washington and chinese
# academy of
#
#
#
#
# cats are believed to
# have been attracted to the
# village by rodents
#
#
#
#
# turn were attracted
# by grain cultivated and
# stored by humans in
#
#
#
#
# depicted in cat
# form sometimes taking on the
# war like aspect of
#
#
#
#
# the domestic cat
# from egypt to europe in
# roman aquitaine
#
#
#
#
# a first or second
# century engraving of
# a young girl holding
#
#
#
#
# of two earliest
# depictions of the roman
# domesticated
#
#
#
#
# were already kept
# in europe prior to the
# roman empire
#
#
#
#
# have been present in
# britain in the late iron
# age domestic cats
#
#
#
#
# much of the rest of
# the world during the age of
# discovery as
#
#
#
#
# on sailing ships to
# control shipboard rodents and
# as good luck charms see
#
#
#
#
# s cat several
# ancient religions believed
# cats are exalted
#
#
#
#
# souls companions or
# guides for humans that are all
# knowing but mute so
#
#
#
#
# cat is a symbol
# of good fortune although no
# species are sacred
#
#
#
#
# some western writers
# have stated muhammad had
# a favorite cat
#
#
#
#
# he is reported
# to have loved cats so much he
# would do without his
#
#
#
#
# rather than disturb
# one that was sleeping on it
# the story has no
#
#
#
#
# in early muslim
# writers and seems to confuse
# a story of a
#
#
#
#
# norse mythology
# is depicted as riding
# a chariot drawn
#
#
#
#
# cats an example
# would be the belief that a
# black cat crossing one
#
#
#
#
# used to augment a
# witch s powers and skills the
# killing of cats in
#
#
#
#
# according to a
# myth in many cultures cats
# have multiple lives
#
#
#
#
# many countries they
# are believed to have nine lives
# but in italy
#
#
#
#
# some spanish speaking
# regions they are said to have
# seven lives while in
#
#
#
#
# credence to this myth
# is the fact that falling cats
# often land on their
#
#
#
#
# to twist their bodies
# around nonetheless cats can
# still be injured or
#
#
#
#
# fall depictions of
# cats in art jar with small looped
# handles and feline
#
#
#
#
# museum pair of
# cat bookends manufactured
# by chase brass copper
#
#
#
#
# also animal
# testing on cats animal
# track cancer in cats
#
#
#
#
# cat and mouse cat and
# mouse game cat lady cats on
# the internet cat
#
#
#
#
# breeds list of cats list
# of cat documentaries
# list of fictional
#
#
#
#
# other felines pet
# door including cat flap pet
# first aid popular
#
#
#
#
# trap neuter return
# cats by location cats in
# ancient egypt cats
#
#
#
#
# cats in new zealand
# cats in the united states
# references a
#
#
#
#
# p retrieved april
# a b c d e f g
# h i driscoll c
#
#
#
#
# proceedings of the
# national academy
# of sciences of
#
#
#
#
# the english language
# education yahoo com
# online ed boston
#
#
#
#
# functional study
# the american journal
# of psychology
#
#
#
#
# of feral and free
# ranging cats on bird species
# of conservation
#
#
#
#
# study traces cat
# s ancestry to middle
# east new york times new
#
#
#
#
# names authors list link
# a b oldest known pet cat
# year old burial
#
#
#
#
# sun z earliest
# domestic cats in china
# identified as
#
#
#
#
# original on
# june a b c d e f
# g h macdonald
#
#
#
#
# l rogers q r
# morris j g nutrition
# of the domestic
#
#
#
#
# b baron alan
# stewart c n warren j
# m january
#
#
#
#
# terry w
# robinson s genetics
# for cat breeders and
#
#
#
#
# catalogue of the
# specimens of caucasian
# large mammalian
#
#
#
#
# collection of the
# national museum of
# georgia caucasian
#
#
#
#
# c mattern michelle
# y mclennan deborah
# a phylogeny
#
#
#
#
# doi j tb x
# masuda r lopez j
# v slattery j
#
#
#
#
# cat breeds genetic
# evaluations of breeds
# and worldwide random
#
#
#
#
# john w s
# evidence suggesting pre
# adaptation to
#
#
#
#
# f allen j a
# robinson i h feral
# cats their role in the
#
#
#
#
# e alves p c
# hybridization versus
# conservation are
#
#
#
#
# cats threatening the
# genetic integrity
# of wildcats felis
#
#
#
#
# words and their background
# new york d appleton and
# company via
#
#
#
#
# dictionary of
# the english language new york
# gramercy books p
#
#
#
#
# retrieved october
# hartwell sarah dwarf midget
# and miniature
#
#
#
#
# january a
# b wilson julia cat world
# records cat world com
#
#
#
#
# retrieved september
# feline veterinary care
# by the boston cat
#
#
#
#
# hospital retrieved
# january domestic
# cat animal bytes
#
#
#
#
# without citing them
# in detail a b walker
# warren f study
#
#
#
#
# cat with reference
# to human beings th
# revised ed thomson
#
#
#
#
# december retrieved
# september a b c d
# e case linda p
#
#
#
#
# nutrition and health
# ames ia iowa state
# university
#
#
#
#
# the school journal e
# l kellogg co lxi retrieved
# november a b
#
#
#
#
# a variable
# regulatory output
# responsible for
#
#
#
#
# names authors list link
# kahn cynthia m line scott
# hollander joseph
#
#
#
#
# do cats sweat cat health
# com retrieved february
# adams t morgan
#
#
#
#
# hunter w
# s holmes k r temperature
# regulation of
#
#
#
#
# mild cold and severe
# heat stress journal of applied
# physiology
#
#
#
#
# to meet its water
# requirements solely from
# a diet of fish
#
#
#
#
# of sea water with
# special reference to the
# cat american
#
#
#
#
# b zoran d l
# the carnivore connection
# to nutrition in
#
#
#
#
# the american
# veterinary medical
# association
#
#
#
#
# on may gray c m
# sellon r k freeman l
# m nutritional
#
#
#
#
# the american
# veterinary medical
# association
#
#
#
#
# s bruce l l cat
# color vision the effect
# of stimulus size
#
#
#
#
# april the spectral
# sensitivity of dark
# and light adapted
#
#
#
#
# communication
# journal of comparative
# psychology doi
#
#
#
#
# sommerville b a
# olfactory awareness
# applied animal
#
#
#
#
# catnip its uses
# and effects past and present
# the canadian
#
#
#
#
# school of medical
# engineering retrieved may
# this tertiary source
#
#
#
#
# information from
# other sources but does not
# name them a b c
#
#
#
#
# the life span of the
# common cat about com home
# retrieved september
#
#
#
#
# example me wow
# texas woman says cat is
# years old although she
#
#
#
#
# oldest cat ever
# was creme puff who sic was born
# on august and lived
#
#
#
#
# for the prevention
# of cruelty to animals
# retrieved december
#
#
#
#
# a january
# evaluation of the
# effect of a long
#
#
#
#
# trap neuter return
# and adoption program on
# a free roaming cat
#
#
#
#
# the american
# veterinary medical
# association
#
#
#
#
# the american
# veterinary medical
# association
#
#
#
#
# number of the four
# remaining colony cats
# at the parliament
#
#
#
#
# sanctuary in
# ottawa ontario
# canada were and
#
#
#
#
# old in a beloved
# parliament hill attraction
# uses up its nine
#
#
#
#
# animal welfare
# forum the welfare of cats
# november zorro
#
#
#
#
# trap neuter return
# humanely stabilized and
# reduced in size the
#
#
#
#
# when zorro was the
# last remaining living cat
# advocates report
#
#
#
#
# return approach to
# stray cats los angeles times
# september the last
#
#
#
#
# cat in a managed
# colony in washington
# d c died at age
#
#
#
#
# eventually
# reduced to zero alley
# cat allies accessed
#
#
#
#
# information from
# other sources but does not
# name them williams r
#
#
#
#
# t february
# species variations in
# the pathways of drug
#
#
#
#
# cats as sentinel
# species environmental
# health perspectives a
#
#
#
#
# c g smith r a
# nicholson s acute pine
# sol toxicity
#
#
#
#
# a domestic cat
# veterinary and human
# toxicology
#
#
#
#
# retrieved august plants
# and your cat cat fanciers
# association
#
#
#
#
# the original
# on january retrieved
# may langston cathy
#
#
#
#
# renal failure caused
# by lily ingestion in
# six cats journal of
#
#
#
#
# the american
# veterinary medical
# association
#
#
#
#
# o brien p c
# the genome phylogeny
# of domestic cat
#
#
#
#
# by comparative
# chromosome painting and g
# banding chromosome
#
#
#
#
# j u mullikin
# j c smith d r et al
# initial sequence
#
#
#
#
# brien stephen j
# johnson w driscoll
# c pontius j
#
#
#
#
# menotti raymond
# m state of cat genomics
# trends in genetics
#
#
#
#
# o brien stephen
# j menotti raymond m
# murphy w
#
#
#
#
# the feline genome
# project annual review
# of genetics doi
#
#
#
#
# sharing between the
# european wildcat the
# domestic cat and
#
#
#
#
# their hybrids journal
# of zoology doi j
# x a b barratt
#
#
#
#
# s cunningham j
# t circadian rhythms
# in food intake and
#
#
#
#
# processes doi a
# b crowell davis s l
# curtis t m knowles
#
#
#
#
# the original
# on june mccomb k taylor
# a m wilson c
#
#
#
#
# the original
# on february retrieved
# september a b
#
#
#
#
# natoli e the
# social function of tail up
# in the domestic
#
#
#
#
# on july retrieved
# february the cat s
# remarkable purr
#
#
#
#
# a b ewing tom
# a hairy dilemma when
# hair balls aren t
#
#
#
#
# on august retrieved
# december archive a b
# lindell ellen m
#
#
#
#
# types of aggression
# sexes of fighting pairs and
# effectiveness of
#
#
#
#
# the american
# veterinary medical
# association
#
#
#
#
# aggression between
# family cats the humane
# society of
#
#
#
#
# original on
# december pedersen n
# c yamamoto
#
#
#
#
# hansen h feline
# immunodeficiency
# virus infection
#
#
#
#
# a b c d woods
# m mcdonald ra harris
# s predation of
#
#
#
#
# of crops in warmer
# climates and their control page
# dennis s hill a
#
#
#
#
# r will tom marra
# peter p january
# the impact of free
#
#
#
#
# cats on wildlife of
# the united states nature
# communications
#
#
#
#
# we estimate that
# free ranging domestic cats
# kill billion birds and
#
#
#
#
# annually a
# b natalie angier
# january that
#
#
#
#
# cuddly kitty is
# deadlier than you think the
# new york times retrieved
#
#
#
#
# do cats play with their
# food arizona daily
# sun retrieved august
#
#
#
#
# the predatory
# and social behavior of
# domestic and wild
#
#
#
#
# purr and everything
# else you ever wanted to
# know crown publishing
#
#
#
#
# sugar levels and
# renal sugar excretion
# after the intake
#
#
#
#
# information from
# other sources but does not
# name them scientists
#
#
#
#
# catch a feral cat
# killing a large mammal on
# camera for the
#
#
#
#
# retrieved september
# wade nicholas november
# for cats a big gulp
#
#
#
#
# touch of the tongue new
# york times retrieved november
# poirier f e
#
#
#
#
# applied animal
# behaviour science doi s
# hall sarah l june
#
#
#
#
# the influence of
# hunger on object play by
# adult domestic
#
#
#
#
# sources but does not
# name them laser standards and
# classifications
#
#
#
#
# on amazon com
# cats can get frustrated from
# lasers a b c
#
#
#
#
# systems retrieved june
# aronson l r cooper
# m l penile spines
#
#
#
#
# of cat care how to
# raise a happy and healthy
# cat translated from
#
#
#
#
# m v johnston s
# d early age neutering
# of dogs and cats in
#
#
#
#
# characteristics
# and neuter status of cats
# living in households
#
#
#
#
# the american
# veterinary medical
# association
#
#
#
#
# invasions in the
# antarctic extent impacts
# and implications
#
#
#
#
# b alonso j
# a review of feral cat
# eradication
#
#
#
#
# september retrieved
# august a b what is the
# difference between
#
#
#
#
# cat and a feral
# cat humane society
# of the united
#
#
#
#
# the original
# on may torre argentina
# cat shelter retrieved
#
#
#
#
# june rowan andrew
# n deborah j salem
# november the state
#
#
#
#
# robertson i d
# survey of predation by
# domestic cats aust
#
#
#
#
# p boots m gaston
# k j urban bird declines
# and the fear of cats
#
#
#
#
# mammal invaders
# on islands impact control
# and control impact
#
#
#
#
# j hauber m e
# imber m j stamp r k
# clout m n spatial
#
#
#
#
# an oceanic
# island system proceedings
# of the national
#
#
#
#
# dickman overview
# of the impacts of feral
# cats on australian
#
#
#
#
# o food habits and
# prey impact by feral and
# house based domestic
#
#
#
#
# b lawton j h
# predation by domestic
# cats in an english
#
#
#
#
# village journal of
# zoology london doi
# j tb x a
#
#
#
#
# mead c j ringed birds
# killed by cats mammal review
# doi j tb x
#
#
#
#
# you thought watching cat
# videos was harmless fun
# think again retrieved
#
#
#
#
# cats and their impact
# on prey populations in
# the domestic cat
#
#
#
#
# m j long a j
# wege d c endemic bird
# areas of the
#
#
#
#
# at some islands in
# the african sector of
# the southern ocean
#
#
#
#
# p evans p g
# h schreiber r w
# international
#
#
#
#
# r a new zealand
# bird life past and present stiles
# galbreath r brown d
#
#
#
#
# the lighthouse keeper
# s cat discovery and
# extinction of the
#
#
#
#
# december a b
# dowding j e murphy e
# c the impact of
#
#
#
#
# in new zealand a
# conservation perspective
# biological
#
#
#
#
# s maxwell t loss
# and recovery of wings in
# stick insects nature
#
#
#
#
# resurrection of
# birds on pacific islands
# earth science reviews
#
#
#
#
# unabashedly
# embracing their love of cats
# new york times retrieved
#
#
#
#
# companionship and
# love of animals drive pet
# ownership gallup
#
#
#
#
# retrieved october
# a primer on animal
# rights leading experts
#
#
#
#
# proposes cat and
# dog fur ban bbc news
# november retrieved
#
#
#
#
# the original
# on february retrieved
# december witchcraft
#
#
#
#
# magic in europe
# volume the middle ages
# karen jolly a
#
#
#
#
# c black paterson
# tony april switzerland
# finds a way to skin
#
#
#
#
# launches national
# cat census cbc news
# retrieved september
#
#
#
#
# facts about common
# domestic pets pravda ru
# retrieved october
#
#
#
#
# cat s ancestry
# to middle east new york times
# retrieved october
#
#
#
#
# stanley d gehrt seth
# p d riley brian l
# cypher march urban
#
#
#
#
# could be oldest pet
# cat new scientist retrieved
# november walton
#
#
#
#
# ancient burial
# looks like human and pet cat
# cnn retrieved
#
#
#
#
# november driscoll
# ca menotti raymond m
# roca al the near
#
#
#
#
# retrieved september
# a b c mason i l
# evolution of
#
#
#
#
# veyne paul the household
# and its freed slaves the roman
# empire arthur
#
#
#
#
# december retrieved
# december geyer georgie
# anne when cats reigned like
#
#
#
#
# on the trail of the
# sacred cats kansas city
# missouri andrews
#
#
#
#
# warns about high rise
# falls by cats new york about
# com retrieved april
#
#
# [[[u'this', u'article', u'is'], [u'about', u'the', u'cat', u'species', u'that'], [u'is', u'commonly', u'kept']], [[u'typically', u'furry'], [u'carnivorous', u'mammal', u'they'], [u'are', u'often', u'called', u'house']], [[u'as', u'indoor', u'pets', u'or'], [u'simply', u'cats', u'when', u'there', u'is', u'no'], [u'need', u'to', u'distinguish']], [[u'and', u'felines', u'cats', u'are'], [u'often', u'valued', u'by', u'humans'], [u'for', u'companionship']], [[u'ability', u'to'], [u'hunt', u'vermin', u'there', u'are', u'more', u'than'], [u'cat', u'breeds', u'different']], [[u'associations'], [u'proclaim', u'different', u'numbers'], [u'according', u'to', u'their']], [[u'a', u'strong', u'flexible'], [u'body', u'quick', u'reflexes', u'sharp'], [u'retractable', u'claws']], [[u'and', u'predatory'], [u'ecological', u'niche', u'cats'], [u'can', u'hear', u'sounds', u'too', u'faint']], [[u'in', u'frequency', u'for'], [u'human', u'ears', u'such', u'as', u'those', u'made'], [u'by', u'mice', u'and', u'other']], [[u'small', u'animals', u'they'], [u'can', u'see', u'in', u'near', u'darkness', u'like'], [u'most', u'other', u'mammals']], [[u'have', u'poorer', u'color'], [u'vision', u'and', u'a', u'better', u'sense'], [u'of', u'smell', u'than', u'humans']], [[u'cats', u'despite', u'being'], [u'solitary', u'hunters', u'are'], [u'a', u'social', u'species']], [[u'and', u'grunting', u'as', u'well'], [u'as', u'cat', u'pheromones', u'and', u'types'], [u'of', u'cat', u'specific']], [[u'have', u'a', u'high', u'breeding'], [u'rate', u'under', u'controlled', u'breeding'], [u'they', u'can', u'be', u'bred', u'and']], [[u'shown', u'as', u'registered'], [u'pedigree', u'pets', u'a', u'hobby'], [u'known', u'as', u'cat', u'fancy']], [[u'failure', u'to', u'control'], [u'the', u'breeding', u'of', u'pet', u'cats', u'by'], [u'neutering', u'and', u'the']], [[u'of', u'former', u'household'], [u'pets', u'has', u'resulted', u'in', u'large'], [u'numbers', u'of', u'feral']], [[u'other', u'factors', u'to'], [u'the', u'extinction', u'of', u'many'], [u'bird', u'species', u'cats', u'have']], [[u'extirpate', u'a', u'bird'], [u'species', u'within', u'specific'], [u'regions', u'and', u'may', u'have']], [[u'to', u'the', u'extinction'], [u'of', u'isolated', u'island'], [u'populations', u'cats']], [[u'for', u'the', u'extinction'], [u'of', u'species', u'of', u'birds', u'and', u'the'], [u'presence', u'of', u'feral']], [[u'reintroduction'], [u'in', u'otherwise', u'suitable'], [u'locations', u'since', u'cats']], [[u'were', u'venerated'], [u'in', u'ancient', u'egypt', u'they', u'were'], [u'commonly', u'believed']], [[u'in', u'west', u'asia', u'a'], [u'study', u'found', u'that', u'leopard', u'cats'], [u'were', u'undergoing']], [[u'domesticated'], [u'populations', u'of', u'today'], [u'as', u'of', u'a', u'study']], [[u'cats', u'are', u'the', u'second'], [u'most', u'popular', u'pet', u'in', u'the'], [u'united', u'states', u'by']], [[u'are', u'a', u'rapidly'], [u'evolving', u'family', u'of'], [u'mammals', u'that', u'share', u'a']], [[u'common', u'ancestor'], [u'only', u'million', u'years', u'ago'], [u'and', u'include', u'lions']], [[u'part', u'of', u'the', u'genus'], [u'felis', u'which', u'is', u'a', u'group', u'of'], [u'small', u'cats', u'containing']], [[u'species', u'depending'], [u'upon', u'classification'], [u'scheme', u'members', u'of', u'the']], [[u'worldwide', u'and', u'include'], [u'the', u'jungle', u'cat', u'felis', u'chaus'], [u'of', u'southeast', u'asia']], [[u'the', u'arabian'], [u'sand', u'cat', u'f', u'margarita'], [u'among', u'others', u'the']], [[u'this', u'has', u'resulted'], [u'in', u'mixed', u'usage', u'of', u'the', u'terms'], [u'as', u'the', u'domestic']], [[u'on', u'zoological'], [u'nomenclature', u'fixed', u'the', u'name'], [u'for', u'wildcats', u'as', u'f']], [[u'synonym', u'proposed'], [u'sometimes', u'the', u'domestic', u'cat'], [u'has', u'been', u'called', u'felis']], [[u'proposed', u'by', u'german'], [u'naturalist', u'j', u'c', u'p'], [u'erxleben', u'in', u'but']], [[u ...
